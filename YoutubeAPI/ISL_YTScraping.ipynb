# %%
# api_key="AIzaSyCT-GqWJUIfbTwVsEgtz6BYeAfmKk6DDIo" # set the api key

# import pafy
from apiclient.discovery import build
youtube = build('youtube', 'v3', developerKey=api_key)

# %%
def get_channel_videos(channel_id):
    res=youtube.channels().list(id=channel_id,part='contentDetails').execute()
    playlist_id=res['items'][0]['contentDetails']['relatedPlaylists']['uploads']
    videos=[]
    next_page_token=None

    while 1:
        res=youtube.playlistItems().list(playlistId=playlist_id,part='snippet',maxResults=50,pageToken=next_page_token).execute()
        videos+=res['items']
        next_page_token=res.get('nextPageToken')
        if next_page_token is None:
            break
    
    return videos

# %%
videos = get_channel_videos('UCmM7KPLEthAXiPVAgBF6rhA')

# %%
# len(videos)

# %%
# importing pafy
# import pafy 

arr = [[video['snippet']['title'],"https://www.youtube.com/watch?v="+ str(video['snippet']['resourceId']['videoId']),video['snippet']['resourceId']['videoId']]  for video in videos if (int(video['snippet']['publishedAt'].split('-')[0])==2011)]

# %%
for video in videos:
  print(video)
# Out:
# {'kind': 'youtube#playlistItem', 'etag': 'SQvGgKvLnBLA-Ngyp1Hr1ofa-jI', 'id': 'VVVtTTdLUExFdGhBWGlQVkFnQkY2cmhBLkNtMF9yYnBVemFv', 'snippet': {'publishedAt': '2013-09-13T06:34:01Z', 'channelId': 'UCmM7KPLEthAXiPVAgBF6rhA', 'title': 'An Ant went to a Sugar Hill', 'description': '', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Cm0_rbpUzao/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/Cm0_rbpUzao/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/Cm0_rbpUzao/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'Indian Sign Language RKMVU-CBE', 'playlistId': 'UUmM7KPLEthAXiPVAgBF6rhA', 'position': 0, 'resourceId': {'kind': 'youtube#video', 'videoId': 'Cm0_rbpUzao'}, 'videoOwnerChannelTitle': 'Indian Sign Language RKMVU-CBE', 'videoOwnerChannelId': 'UCmM7KPLEthAXiPVAgBF6rhA'}}
# ...

# %%
# arr

# %%
# Importing library
import csv

# opening the csv file in 'w+' mode
file = open('Videos.csv', 'w+', newline ='')

# writing the data into the file
with file:	
	write = csv.writer(file)
	write.writerows(arr)

# %%
# importing csv module
import csv
from moviepy.editor import VideoFileClip

# csv file name
filename = "Videos.csv"

# initializing the titles and rows list
fields = []
rows = []

# reading csv file
with open(filename, 'r') as csvfile:
	# creating a csv reader object
	csvreader = csv.reader(csvfile)
	
	# extracting field names through first row
	# fields = next(csvreader)

	# extracting each data row one by one
	#for row in csvreader:
	#	rows.append(row)
  
	rows = [ row for  row in csvreader]

	# get total number of rows
	print("Total no. of rows: %d"%(csvreader.line_num))

# printing the field names
# print('Field names are:' + ', '.join(field for field in fields))

# printing first 5 rows
print('\nFirst 5 rows are:\n')
for row in rows[:5]:
	# parsing each column of a row
	for col in row:
		#print("%10s"%col,end=" "),
		print(col)
	print('\n')
	
	clip = VideoFileClip("row[2]")
	print( clip.duration )
# Out:
# Imageio: 'ffmpeg-linux64-v3.3.1' was not found on your computer; downloading it now.
# Try 1. Download from https://github.com/imageio/imageio-binaries/raw/master/ffmpeg/ffmpeg-linux64-v3.3.1 (43.8 MB)
# 45929032/45929032 bytes (100.0%)
#   Done
# File saved as /root/.imageio/ffmpeg/ffmpeg-linux64-v3.3.1.
# Total no. of rows: 3627
#
# First 5 rows are:
#
# tie
# https://www.youtube.com/watch?v=vbsNiOkm0BU
# vbsNiOkm0BU
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-9-82c013205b92> in <module>()
#      39         print('\n')
#      40
# ---> 41         clip = VideoFileClip("row[2]")
#      42         print( clip.duration )
#
# /usr/local/lib/python3.7/dist-packages/moviepy/video/io/VideoFileClip.py in __init__(self, filename, has_mask, audio, audio_buffersize, target_resolution, resize_algorithm, audio_fps, audio_nbytes, verbose, fps_source)
# ...
